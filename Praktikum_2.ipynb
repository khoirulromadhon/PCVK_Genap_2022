# %% [markdown]
# <a href="https://colab.research.google.com/github/khoirulromadhon/PCVK_Genap_2022/blob/main/Praktikum_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Mochi.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Mochi.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384, 0), pt2=(510, 150), color=(0, 255, 0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200, 200), pt2=(300, 300), color=(0, 0, 255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness = 2, lineType = cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape = (512, 512, 3), dtype = np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype = np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1, 1, 2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Pertanyaan
#
#
# 1. Memunculkan ukuran Panjang dan lebar jika menggunakan matplotlib
# 2.	Jumlah pixelnya
# 3.	Dari list 2 dimensi menjadi list 3 dimensi
# 4.	Membaca, Menampilkan, dan konversi citra
# 5.	Menampilkan histogram citra

# %% [markdown]
# Tugas

# %%
#blue_green
img6 = cv.imread('/content/drive/MyDrive/PCVK/Mochi.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img6, cmap='ocean')

# %%
#red_green
img7 = cv.imread('/content/drive/MyDrive/PCVK/Mochi.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img7, cmap='RdYlGn')

# %%
#image baris ke 10-100, kolom 10-100
img8 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img8[10:100, 10:100])

# %%
#image baris ke 5-30, kolom 10-100
img8 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
g = img8[...,1]
plt.imshow(img8[5:30, 0:1000], cmap = 'Greens')

# %%
#5 ukuran rectangle yang berbeda dan warna yang berbeda
img9 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img9, pt1 = (100, 100), pt2 = (200, 200), color = (0, 225, 0), thickness = 20)
cv.rectangle(img9, pt1 = (500, 500), pt2 = (750, 750), color = (0, 0, 0), thickness = 20)
cv.rectangle(img9, pt1 = (1000, 500), pt2 = (1500, 1100), color = (125, 0, 0), thickness = 20)
cv.rectangle(img9, pt1 = (500, 0), pt2 = (700, 300), color = (125, 0, 66), thickness = 20)
cv.rectangle(img9, pt1 = (2000, 50), pt2 = (2400, 500), color = (255, 255, 0), thickness = 20)
plt.imshow(img9)

# %%
#menampilkan image dalam posisi terbalik
img10 = cv.flip(cv.cvtColor(img9, cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(img10)

# %%
#menggambar rectangle dan circle pada wajah kitten
img11 = img
img12 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img12, pt1 = (250, 1000), pt2 = (1000, 1500), color = (125, 255, 0), thickness = 20)
cv.circle(img12, center = (500, 1300), radius = 300, color = (0, 255, 0), thickness = 20)
plt.imshow(img12)

# %%
#menggambar rectangle pada bagian sudut bawah kiri chanel B pada color space RGB
img12 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img12, pt1 = (0, 1500), pt2 = (500,1930), color = (0, 0, 125), thickness = 10)
plt.imshow(img12)

# %%
b = img12[...,0]
g = img12[...,1]
r = img12[...,2]

img13 = plt.imshow(b)
